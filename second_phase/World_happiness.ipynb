# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("world_happiness.csv")
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
df.tail()
# Out:
#      Country                           Region  Happiness Rank  \
# 153   Rwanda               Sub-Saharan Africa             154
# 154    Benin               Sub-Saharan Africa             155
# 155    Syria  Middle East and Northern Africa             156
# 156  Burundi               Sub-Saharan Africa             157
# 157     Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 153                   0.42864  0.59201                        0.55191
# ...

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
df.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df_new = df[df.columns[3:]]
df_new
# Out:
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# 1              7.561         0.04884                   1.30232  1.40223
# 2              7.527         0.03328                   1.32548  1.36058
# 3              7.522         0.03880                   1.45900  1.33095
# 4              7.427         0.03553                   1.32629  1.32261
# ..               ...             ...                       ...      ...
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# ...

# %%
plt.figure(figsize=(18,13), facecolor='white')
plotnumber=1

for col in df_new:
    if plotnumber<=12:
        axes = plt.subplot(3,3,plotnumber)
        sns.distplot(df_new[col])
        plt.xlabel(col,fontsize=18)

    plotnumber+=1
plt.tight_layout()

# %%
df_new.skew()
# Out:
# Happiness Score                  0.097769
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %%
plt.figure(figsize=(18,13), facecolor='white')
plotnumber=1

for col in df_new:
    if plotnumber<=12:
        axes = plt.subplot(3,3,plotnumber)
        sns.histplot(df_new[col])
        plt.xlabel(col,fontsize=18)

    plotnumber+=1
plt.tight_layout()

# %%
df_new.corr()
# Out:
#                                Happiness Score  Standard Error  \
# Happiness Score                       1.000000       -0.177254
# Standard Error                       -0.177254        1.000000
# Economy (GDP per Capita)              0.780966       -0.217651
# Family                                0.740605       -0.120728
# Health (Life Expectancy)              0.724200       -0.310287
# Freedom                               0.568211       -0.129773
# Trust (Government Corruption)         0.395199       -0.178325
# Generosity                            0.180319       -0.088439
# Dystopia Residual                     0.530474        0.083981
#
#                                Economy (GDP per Capita)    Family  \
# Happiness Score                                0.780966  0.740605
# Standard Error                                -0.217651 -0.120728
# Economy (GDP per Capita)                       1.000000  0.645299
# Family                                         0.645299  1.000000
# ...

# %%
corr = df_new.corr()
plt.figure(figsize=(10,8))
sns.heatmap(corr, annot=True)
# Out:
# <Axes: >

# %%
df_new.plot(kind='box',subplots=True,layout=(2,6),figsize=(10,10))
# Out:
# Happiness Score                     Axes(0.125,0.53;0.110714x0.35)
# Standard Error                   Axes(0.257857,0.53;0.110714x0.35)
# Economy (GDP per Capita)         Axes(0.390714,0.53;0.110714x0.35)
# Family                           Axes(0.523571,0.53;0.110714x0.35)
# Health (Life Expectancy)         Axes(0.656429,0.53;0.110714x0.35)
# Freedom                          Axes(0.789286,0.53;0.110714x0.35)
# Trust (Government Corruption)       Axes(0.125,0.11;0.110714x0.35)
# Generosity                       Axes(0.257857,0.11;0.110714x0.35)
# Dystopia Residual                Axes(0.390714,0.11;0.110714x0.35)
# dtype: object

# %%
from scipy.stats import zscore
z=np.abs(zscore(df_new))
z
# Out:
#      Happiness Score  Standard Error  Economy (GDP per Capita)    Family  \
# 0           1.937360        0.805926                  1.369621  1.320281
# 1           1.914581        0.055889                  1.135226  1.514458
# 2           1.884792        0.854487                  1.192861  1.361054
# 3           1.880411        0.531526                  1.525130  1.251922
# 4           1.797179        0.722845                  1.194876  1.221204
# ..               ...             ...                       ...       ...
# 153         1.674055        0.774917                  1.552987  0.800520
# 154         1.783571        0.662582                  1.392303  2.346860
# 155         2.076199        0.132534                  0.455245  1.901086
# 156         2.164688        2.263962                  2.067566  2.118467
# 157         2.222513        1.134182                  1.586334  3.134725
#
#      Health (Life Expectancy)   Freedom  Trust (Government Corruption)  \
# ...

# %%
threshold=3
np.where(z>3)
# Out:
# (array([ 27,  40,  64, 115, 128, 147, 153, 155, 157], dtype=int64),
#  array([6, 1, 1, 1, 7, 3, 6, 8, 3], dtype=int64))

# %%
df= df_new[(z<3).all(axis=1)]
df
# Out:
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# 1              7.561         0.04884                   1.30232  1.40223
# 2              7.527         0.03328                   1.32548  1.36058
# 3              7.522         0.03880                   1.45900  1.33095
# 4              7.427         0.03553                   1.32629  1.32261
# ..               ...             ...                       ...      ...
# 150            3.655         0.05141                   0.46534  0.77115
# 151            3.587         0.04324                   0.25812  0.85188
# 152            3.575         0.03084                   0.31982  0.30285
# 154            3.340         0.03656                   0.28665  0.35386
# 156            2.905         0.08658                   0.01530  0.41587
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# ...

# %%
df.shape
# Out:
# (149, 9)

# %%
X = df.drop(columns = ['Happiness Score'])
Y = df['Happiness Score']

# %%
X
# Out:
#      Standard Error  Economy (GDP per Capita)   Family  \
# 0           0.03411                   1.39651  1.34951
# 1           0.04884                   1.30232  1.40223
# 2           0.03328                   1.32548  1.36058
# 3           0.03880                   1.45900  1.33095
# 4           0.03553                   1.32629  1.32261
# ..              ...                       ...      ...
# 150         0.05141                   0.46534  0.77115
# 151         0.04324                   0.25812  0.85188
# 152         0.03084                   0.31982  0.30285
# 154         0.03656                   0.28665  0.35386
# 156         0.08658                   0.01530  0.41587
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                     0.94143  0.66557                        0.41978
# 1                     0.94784  0.62877                        0.14145
# 2                     0.87464  0.64938                        0.48357
# ...

# %%
Y
# Out:
# 0      7.587
# 1      7.561
# 2      7.527
# 3      7.522
# 4      7.427
#        ...
# 150    3.655
# 151    3.587
# 152    3.575
# 154    3.340
# 156    2.905
# Name: Happiness Score, Length: 149, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size = 0.33, random_state=43)
print('Training feature matrix size:',X_train.shape)
print('Training target vector size:',Y_train.shape)
print('Test feature matrix size:',X_test.shape)
print('Test target vector size:',Y_test.shape)
# Out:
# Training feature matrix size: (99, 8)
# Training target vector size: (99,)
# Test feature matrix size: (50, 8)
# Test target vector size: (50,)

# %%
from sklearn.metrics import r2_score
maxr2_score = 0
maxrs = 0
for i in range(1,200):
    X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.33, random_state=i)
    lr = LinearRegression()
    lr.fit(X_train,Y_train)
    y_pre = lr.predict(X_test)
    r2 = r2_score(Y_test,y_pre)
    if r2>maxr2_score:
        maxr2_score=r2
        maxrs=i
print('Best accuracy:', maxr2_score, 'Random_state:', maxrs)
# Out:
# Best accuracy: 0.9999999506659051 Random_state: 8

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size = 0.33, random_state = 8)
lr = LinearRegression()
lr.fit(X_train,Y_train)
lr.score(X_train,Y_train)
pred = lr.predict(X_test)
print("Predict value: ", pred)
print('\n')
print("Actual value: ", Y_test)
# Out:
# Predict value:  [7.42687115 6.50502927 6.57499335 5.58866097 4.88443596 6.32885959
#  6.79773843 3.65506584 4.03308244 5.21193164 4.25197766 6.485079
#  3.78080599 5.87827729 4.51229176 3.9307802  3.58686317 4.29251612
#  5.42851447 4.83917069 5.84754927 7.56083256 2.90465173 5.0130633
#  4.87418756 7.58687728 3.65593654 7.52214668 6.94018481 4.55065508
#  5.9837143  7.19977093 6.81023816 4.34997661 5.39865966 5.25278205
#  4.68555153 5.05731752 6.41119708 4.86723349 4.507257   6.00271434
#  5.19384781 5.77035697 4.60975333 5.88901828 5.98699165 6.1227538
#  5.00700911 3.68089696]
#
#
# Actual value:  4      7.427
# 30     6.505
# 28     6.575
# 68     5.589
# 97     4.885
# 35     6.329
# 23     6.798
# 150    3.655
# 136    4.033
# 79     5.212
# 132    4.252
# 31     6.485
# 145    3.781
# 52     5.878
# 121    4.512
# 140    3.931
# 151    3.587
# 130    4.292
# 72     5.429
# 102    4.839
# 54     5.848
# 1      7.561
# 156    2.905
# 91     5.013
# 99     4.874
# 0      7.587
# ...

# %%
print("MAE: ", mean_absolute_error(Y_test,pred))
print("MSE: ", mean_squared_error(Y_test,pred))
print("RMSE: ", np.sqrt(mean_squared_error(Y_test,pred)))
print("\n")

from sklearn.metrics import r2_score
print("R2_score: ", r2_score(Y_test,pred))
# Out:
# MAE:  0.00021368944335304897
# MSE:  6.871106430165839e-08
# RMSE:  0.00026212795406377093
#
#
# R2_score:  0.9999999506659051

# %%
rf = RandomForestRegressor(n_estimators = 100)
rf.fit(X_train, Y_train)
rf.score(X_train,Y_train)
pred_ = rf.predict(X_test)
print(rf, ':')
print("MAE: ", mean_absolute_error(Y_test,pred_))
print("MSE: ", mean_squared_error(Y_test,pred_))
print("RMSE: ", np.sqrt(mean_squared_error(Y_test,pred_)))
print("\n")

print("R2_score: ", r2_score(Y_test,pred_))
# Out:
# RandomForestRegressor() :
# MAE:  0.2589318000000003
# MSE:  0.10365835323000018
# RMSE:  0.3219601733599983
#
#
# R2_score:  0.9255739800925271

# %%
svr = SVR()
svr.fit(X_train, Y_train)
svr.score(X_train,Y_train)
pred_ = svr.predict(X_test)
print(svr, ':')
print("MAE: ", mean_absolute_error(Y_test,pred_))
print("MSE: ", mean_squared_error(Y_test,pred_))
print("RMSE: ", np.sqrt(mean_squared_error(Y_test,pred_)))
print("\n")

print("R2_score: ", r2_score(Y_test,pred_))
# Out:
# SVR() :
# MAE:  0.0790040764312801
# MSE:  0.011887372688552325
# RMSE:  0.10902922859743769
#
#
# R2_score:  0.9914649441285

# %%
dtc = DecisionTreeRegressor()
dtc.fit(X_train, Y_train)
dtc.score(X_train,Y_train)
pred_ = dtc.predict(X_test)
print(dtc, ':')
print("MAE: ", mean_absolute_error(Y_test,pred_))
print("MSE: ", mean_squared_error(Y_test,pred_))
print("RMSE: ", np.sqrt(mean_squared_error(Y_test,pred_)))
print("\n")

print("R2_score: ", r2_score(Y_test,pred_))
# Out:
# DecisionTreeRegressor() :
# MAE:  0.4978
# MSE:  0.38366856
# RMSE:  0.619409848161942
#
#
# R2_score:  0.7245284823204461

# %%
lr = LinearRegression()
lr.fit(X_train, Y_train)
lr.score(X_train,Y_train)
pred_ = lr.predict(X_test)
print(lr, ':')
print("MAE: ", mean_absolute_error(Y_test,pred_))
print("MSE: ", mean_squared_error(Y_test,pred_))
print("RMSE: ", np.sqrt(mean_squared_error(Y_test,pred_)))
print("\n")

print("R2_score: ", r2_score(Y_test,pred_))
# Out:
# LinearRegression() :
# MAE:  0.00021368944335304897
# MSE:  6.871106430165839e-08
# RMSE:  0.00026212795406377093
#
#
# R2_score:  0.9999999506659051

# %%
from sklearn.model_selection import cross_val_score
score = cross_val_score(lr, X, Y, cv=5)
print("Cross Validation : ")
print("Score: ", score)
print("Mean : ", score.mean())
print("Standard Deviation: ", score.std())
# Out:
# Cross Validation :
# Score:  [0.99999943 0.99999847 0.99999831 0.99999509 0.99999933]
# Mean :  0.9999981234686345
# Standard Deviation:  1.5837827108856898e-06

# %%
import pickle
filename = 'World_Happiness.pkl'
pickle.dump(lr,open(filename,'wb'))

# %%
loaded_model = pickle.load(open(filename, 'rb'))

# %%
loaded_model
# Out:
# LinearRegression()
