# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.columns.to_series().groupby(df.dtypes).groups
# Out:
# {int64: ['PassengerId', 'Survived', 'Pclass', 'SibSp', 'Parch'], float64: ['Age', 'Fare'], object: ['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked']}

# %%
plt.figure(figsize=(7,5))
sns.heatmap(df.isnull(),cmap='cool_r')
plt.show()

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %%
titanic= df.drop(columns='Cabin', axis=1)

# %%
titanic['Age'].fillna(titanic['Age'].mean(), inplace=True)

# %%
titanic['Embarked'].mode()
# Out:
# 0    S
# Name: Embarked, dtype: object

# %%
titanic['Embarked'].fillna(titanic['Embarked'].mode()[0], inplace=True)

# %%
titanic.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
titanic.replace({'Sex':{'male':0,'female':1}, 'Embarked':{'S':0,'C':1,'Q':2}}, inplace=True)

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1      0
# 2                             Heikkinen, Miss. Laina    1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1      0
# 4                           Allen, Mr. William Henry    0  35.0      0      0
#
#              Ticket     Fare  Embarked
# 0         A/5 21171   7.2500         0
# 1          PC 17599  71.2833         1
# 2  STON/O2. 3101282   7.9250         0
# 3            113803  53.1000         0
# 4            373450   8.0500         0

# %%
titanic.plot(kind='box',subplots=True,layout=(2,6),figsize=(10,10))
# Out:
# PassengerId       Axes(0.125,0.53;0.110714x0.35)
# Survived       Axes(0.257857,0.53;0.110714x0.35)
# Pclass         Axes(0.390714,0.53;0.110714x0.35)
# Sex            Axes(0.523571,0.53;0.110714x0.35)
# Age            Axes(0.656429,0.53;0.110714x0.35)
# SibSp          Axes(0.789286,0.53;0.110714x0.35)
# Parch             Axes(0.125,0.11;0.110714x0.35)
# Fare           Axes(0.257857,0.11;0.110714x0.35)
# Embarked       Axes(0.390714,0.11;0.110714x0.35)
# dtype: object

# %%
titanic.drop(columns = ['PassengerId','Name','Survived','Ticket'],axis=1)
# Out:
#      Pclass  Sex        Age  SibSp  Parch     Fare  Embarked
# 0         3    0  22.000000      1      0   7.2500         0
# 1         1    1  38.000000      1      0  71.2833         1
# 2         3    1  26.000000      0      0   7.9250         0
# 3         1    1  35.000000      1      0  53.1000         0
# 4         3    0  35.000000      0      0   8.0500         0
# ..      ...  ...        ...    ...    ...      ...       ...
# 886       2    0  27.000000      0      0  13.0000         0
# 887       1    1  19.000000      0      0  30.0000         0
# 888       3    1  29.699118      1      2  23.4500         0
# 889       1    0  26.000000      0      0  30.0000         1
# 890       3    0  32.000000      0      0   7.7500         2
#
# [891 rows x 7 columns]

# %%
X = titanic.drop(columns = ['PassengerId','Name','Survived','Ticket'],axis=1)
Y = titanic['Survived']

# %%
X
# Out:
#      Pclass  Sex        Age  SibSp  Parch     Fare  Embarked
# 0         3    0  22.000000      1      0   7.2500         0
# 1         1    1  38.000000      1      0  71.2833         1
# 2         3    1  26.000000      0      0   7.9250         0
# 3         1    1  35.000000      1      0  53.1000         0
# 4         3    0  35.000000      0      0   8.0500         0
# ..      ...  ...        ...    ...    ...      ...       ...
# 886       2    0  27.000000      0      0  13.0000         0
# 887       1    1  19.000000      0      0  30.0000         0
# 888       3    1  29.699118      1      2  23.4500         0
# 889       1    0  26.000000      0      0  30.0000         1
# 890       3    0  32.000000      0      0   7.7500         2
#
# [891 rows x 7 columns]

# %%
Y
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

from sklearn.metrics import mean_squared_error,r2_score

# %%
x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=0.2,random_state=2)

# %%
x_train.shape
# Out:
# (712, 7)

# %%
from sklearn.metrics import r2_score
maxr2_score = 0
maxrs = 0
for i in range(1,200):
    x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=0.33, random_state=i)
    lr = LinearRegression()
    lr.fit(X_train,Y_train)
    y_pre = lr.predict(X_test)
    r2 = r2_score(Y_test,y_pre)
    if r2>maxr2_score:
        maxr2_score=r2
        maxrs=i
print('Best accuracy:', maxr2_score, 'Random_state:', maxrs)
# Out:
# Best accuracy: 0.34795944273060886 Random_state: 1

# %%
from sklearn.linear_model import LogisticRegression

x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=0.33, random_state=1)
lr = LogisticRegression()
lr.fit(x_train,y_train)
predlr = lr.predict(x_test)
pred_trainlr = lr.predict(x_train)
print('Test_Accuracy', accuracy_score(y_test,predlr))
print('Train_Accuracy', accuracy_score(y_train,pred_trainlr))
print(confusion_matrix(y_test,predlr))
print(classification_report(y_test,predlr))
rfs = r2_score(y_test,predlr)
print('R2_score: ',rfs)
# Out:
# Test_Accuracy 0.7796610169491526
# Train_Accuracy 0.8154362416107382
# [[146  28]
#  [ 37  84]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.84      0.82       174
#            1       0.75      0.69      0.72       121
#
#     accuracy                           0.78       295
#    macro avg       0.77      0.77      0.77       295
# weighted avg       0.78      0.78      0.78       295
#
# R2_score:  0.0892466989645675

# %%
from sklearn.tree import DecisionTreeClassifier

dt = DecisionTreeClassifier()
dt.fit(x_train,y_train)
preddt = dt.predict(x_test)
pred_traindt = dt.predict(x_train)
print('Test_Accuracy', accuracy_score(y_test,preddt))
print('Train_Accuracy', accuracy_score(y_train,pred_traindt))
print(confusion_matrix(y_test,preddt))
print(classification_report(y_test,preddt))
rfs = r2_score(y_test,preddt)
print('R2_score: ',rfs)
# Out:
# Test_Accuracy 0.7423728813559322
# Train_Accuracy 0.9916107382550335
# [[142  32]
#  [ 44  77]]
#               precision    recall  f1-score   support
#
#            0       0.76      0.82      0.79       174
#            1       0.71      0.64      0.67       121
#
#     accuracy                           0.74       295
#    macro avg       0.73      0.73      0.73       295
# weighted avg       0.74      0.74      0.74       295
#
# R2_score:  -0.06488078274912112

# %%
from sklearn.svm import SVC

svc = SVC()
svc.fit(x_train,y_train)
predsvc = svc.predict(x_test)

print('Test_Accuracy', accuracy_score(y_test,predsvc))
print(confusion_matrix(y_test,predsvc))
print(classification_report(y_test,predsvc))
rfs = r2_score(y_test,predsvc)
print('R2_score: ',rfs)
# Out:
# Test_Accuracy 0.6542372881355932
# [[153  21]
#  [ 81  40]]
#               precision    recall  f1-score   support
#
#            0       0.65      0.88      0.75       174
#            1       0.66      0.33      0.44       121
#
#     accuracy                           0.65       295
#    macro avg       0.65      0.60      0.59       295
# weighted avg       0.65      0.65      0.62       295
#
# R2_score:  -0.4291821031632941

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier

para = {'criterion':['gini','entrophy'],
        'n_estimators':[100,200,300,400,500]
       }
rf = RandomForestClassifier()
cl = GridSearchCV(rf,para)
cl.fit(x_train,y_train)

print(cl.best_params_)
# Out:
# {'criterion': 'gini', 'n_estimators': 200}

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_estimators=200)
rf.fit(x_train,y_train)
predrf = rf.predict(x_test)

print('Test_Accuracy', accuracy_score(y_test,predrf))
print(confusion_matrix(y_test,predrf))
print(classification_report(y_test,predrf))
rfs = r2_score(y_test,predrf)
print('R2_score: ',rfs)
# Out:
# Test_Accuracy 0.7728813559322034
# [[151  23]
#  [ 44  77]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.87      0.82       174
#            1       0.77      0.64      0.70       121
#
#     accuracy                           0.77       295
#    macro avg       0.77      0.75      0.76       295
# weighted avg       0.77      0.77      0.77       295
#
# R2_score:  0.061223520471169524

# %%
from sklearn.model_selection import cross_val_score
score = cross_val_score(lr, X, Y, cv=5)
print("Cross Validation : ")
print("Score: ", score)
print("Mean : ", score.mean())
print("Standard Deviation: ", score.std())
# Out:
# Cross Validation :
# Score:  [0.79329609 0.78651685 0.79213483 0.76966292 0.8258427 ]
# Mean :  0.7934906785512522
# Standard Deviation:  0.01824787934598037

# %%
import pickle
filename = 'titanic.pkl'
pickle.dump(lr,open(filename,'wb'))

# %%
loaded_model = pickle.load(open('titanic.pkl','rb'))
result = loaded_model.score(x_test,y_test)
print(result)
# Out:
# 0.7796610169491526

# %%
loaded_model = pickle.load(open(filename, 'rb'))

# %%
loaded_model
# Out:
# LogisticRegression()
